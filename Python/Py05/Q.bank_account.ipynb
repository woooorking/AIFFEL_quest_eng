# %% [markdown]
# # 은행계좌 만들기

# %%
#Q1 Account 클래스
class Account:
    account_count = 0 
    def __init__(self, bank, name, balance):
        self.bank = 'SC은행'
        self.name = name
        self.balance = balance
    
    #계좌번호 3자리-2자리-6자리 랜덤하게 생성하기
    import random:
        num1 = str(random.randint(0, 999)).zfill(3)
        num2 = str(random.randint(0, 99)).zfill(2)
        num3 = str(random.randint(0, 999999)).zfill(6)
        self.account_number = num1 + "-" + num2 + "-" + num3

        #Q3생성된 계좌 개수 출력 메서드
        def get_account_num(self):
        print(f"개설된 계좌 총: {Account.account_count}개")


    #입금 매서드
    def deposit(self, amount) :
        if amount >= 1: #1원 이상일때 가능
            self.balance += amount
            self.deposit_count = self.deposit_count +1
            print(f"{amount}원 입금완료")

    #출금 매서드
    def withdraw(self, balance):
        if self.balance >= amount #통장 잔액이 출금하려는 금액만큼 있거다 더 많을때만
            self.balance = self.balance - amount
            print(f"{amount}원 출금 완료")
        else:
            print("잔액이 부족합니다.")
    

    #정보 출력 매서드 추가
    def display_info(self):
    print (f"은행이름:{self.bank},예금주:{self.name}, 계좌번호:{self.account_number}")
 

     #이자 지급하기

     #여러 객체 생성

     #객체 순회 반복문
# Out:
#   Cell In[16], line 10
#     import random:
#                  ^
# SyntaxError: invalid syntax
